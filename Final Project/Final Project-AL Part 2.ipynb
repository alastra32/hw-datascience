# %% [markdown]
# # Final Project - Part 2 - A Lastra

# %% [markdown]
# # Project Design Writeup and Approval Template
#
# Follow this as a guide to completing the project design writeup. The questions for each section are merely there to suggest what the baseline should cover; be sure to use detail as it will make the project much easier to approach as the class moves on.
#
# ### Project Problem and Hypothesis
# * What's the project about? What problem are you solving?
#
# Determine what type of products will customers order according to time of the day using instacart customer order data for 3 Million orders for an unknown time period.
#
#
# * Where does this seem to reside as a machine learning problem? Are you predicting some continuous number, or predicting a binary value?
#
#
# I'd be trying to predict a binary value. This could also be seen as a classification problem.
#
#
# * What kind of impact do you think it could have?
#
# The learnings can be used to predict inventory needs. Moreover, the learnings could also be used to help customers mold or shape their behaviors.
#
#
# * What do you think will have the most impact in predicting the value you are interested in solving for?
#
# The Time of Day, Products, Product Department and possibly day of the week.
#
#
# ### Datasets
# * Description of data set available, at the field level (see table)
#
# orders (3.4m rows, 206k users):
#
# order_id: order identifier
# user_id: customer identifier
# eval_set: which evaluation set this order belongs in (see SET described below)
# order_number: the order sequence number for this user (1 = first, n = nth)
# order_dow: the day of the week the order was placed on
# order_hour_of_day: the hour of the day the order was placed on
# days_since_prior: days since the last order, capped at 30 (with NAs for order_number = 1)
#
#
# products (50k rows):
#
# product_id: product identifier
# product_name: name of the product
# aisle_id: foreign key
# department_id: foreign key
#
#
# aisles (134 rows):
#
# aisle_id: aisle identifier
# aisle: the name of the aisle
#
# departments (21 rows):
#
# department_id: department identifier
# department: the name of the department
#
#
# order_products__SET (30m+ rows):
#
# order_id: foreign key
# product_id: foreign key
# add_to_cart_order: order in which each product was added to cart
# reordered: 1 if this product has been ordered by this user in the past, 0 otherwise
#
#
# where SET is one of the four following evaluation sets (eval_set in orders):
#
# "prior": orders prior to that users most recent order (~3.2m orders)
# "train": training data supplied to participants (~131k orders)
# "test": test data reserved for machine learning competitions (~75k orders)
#
#
#
#
# * If from an API, include a sample return (this is usually included in API documentation!) (if doing this in markdown, use the javacription code tag)
#
# ### Domain knowledge
# * What experience do you already have around this area?
#
# I have a background in Financial Planning and Analysis.
#
#
# * Does it relate or help inform the project in any way?
#
# Not Exactly, it helps as familiarity with planning and analysis but not essential.
#
# * What other research efforts exist?
#
#
# https://tech.instacart.com/3-million-instacart-orders-open-sourced-d40d29ead6f2
#
# https://medium.com/towards-data-science/analysing-shopping-behaviour-of-users-using-machine-learning-part-1-518483e72a2c
#
# ### Project Concerns
# * What questions do you have about your project? What are you not sure you quite yet understand? (The more honest you are about this, the easier your instructors can help).
#
# I am not sure on which regression method or classification method I'll use to determine the solution to my problem.
#
#
# * What are the assumptions and caveats to the problem?
#     * What data do you not have access to but wish you had?
#
#             An easier classification of the products and not having to heavily relay on the provided product departments to get to conclusions.
#
#     * What is already implied about the observations in your data set? For example, if your primary data set is twitter data, it may not be representative of the whole sample (say, predicting who would win an election)
#
#           The data only applies to frequent Instacart customers, only customers that have ordered between 4-100 times have been included in the data.
# * What are the risks to the project?
#     * What's the cost of your model being wrong? (What's the benefit of your model being right?)
#
#             The costs of the model being incorrect in the short term is none, in the long term if it were used for inventory needs could lead to monetary impact. If the predictions were used to aid customer behavior, it would result in bad or futile attempts.
#     * Is any of the data incorrect? Could it be incorrect?
#
#             The amounts of re-orders above 99 isnt clear, the days since last order gets maxed at 30 and the assumptions for what number is each day of the week may be incorrect.
# ### Outcomes
# * What do you expect the output to look like?
#
# A function or algorythm that would help predict the classifiction of each order.
#
# * What does your target audience expect the output to look like?
#
# A formulated argument with explanations of the findings as well as possible future applications.
#
#
# * What gain do you expect from your most important feature on its own?
#
# * How complicated does your model have to be?
#
# Not exactly sure, depends on the accuracy.
#
# * How successful does your project have to be in order to be considered a "success"?
#
# Success would be that it would correctly classify or predict an order 75% of the time.
#
#
# * What will you do if the project is a bust (this happens! but it shouldn't here)?
#
# Look for other possible classifications or predictive models based on the available data.
